# %% [markdown]
# <a href="https://colab.research.google.com/github/BartBennett/SimStudent/blob/main/calculate_pi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
#constants
darts=100000

#arrays
red_dots_x = np.array([])
red_dots_y=np.array([])
blue_dots_x = np.array([])
blue_dots_y=np.array([])

for dart in range(darts):
    x=random.uniform(-1,1)
    y=random.uniform(-1,1)
    if x*x + y*y < 1:
      red_dots_x=np.append(red_dots_x, x)
      red_dots_y=np.append(red_dots_y, y)
    else:
      blue_dots_x=np.append(blue_dots_x, x)
      blue_dots_y=np.append(blue_dots_y, y)

print(4 * red_dots_x.size/darts)

fig=plt.figure()
ax=fig.add_subplot()
ax.set_aspect(1)
plt.scatter(red_dots_x,red_dots_y, s=0.1,c="red")
plt.scatter(blue_dots_x,blue_dots_y, s=0.1,c="blue")
plt.show()
# Out:
# 3.1386
